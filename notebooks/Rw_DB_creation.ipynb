# %%
spark.sql("create database if not exists rw_globalretail")
# Out:
# Out[1]: DataFrame[]

# %%
spark.sql("Show databases").show()
# Out:
# +---------------+
# |   databaseName|
# +---------------+
# |        default|
# |md_globalretail|
# |rw_globalretail|
# +---------------+

# %%
spark.sql("use rw_globalretail")
# Out:
# Out[3]: DataFrame[]

# %%
# %sql
select current_database()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_database()</th></tr></thead><tbody><tr><td>rw_globalretail</td></tr></tbody></table></div>

# %%
# dbutils.fs.mkdirs("/FileStore/GlobalRetail")
# dbutils.fs.mkdirs("/FileStore/GlobalRetail/RawData")
# dbutils.fs.mkdirs("/FileStore/GlobalRetail/RawData/CustomerData")
# dbutils.fs.mkdirs("/FileStore/GlobalRetail/RawData/ProductData")
# dbutils.fs.mkdirs("/FileStore/GlobalRetail/RawData/TransationData")
# Out:
# Out[5]: True

# %%
# dbutils.fs.rm("dbfs:/FileStore/GlobalRetail/raw_data", recurse=True)
# Out:
# Out[6]: False

# %%
# Delete all the files inside  any folder
folder_path = "dbfs:/FileStore/tables"

# List all files in the folder
files = dbutils.fs.ls(folder_path)

# Delete each file in the folder
for file_info in files:
    dbutils.fs.rm(file_info.path)
