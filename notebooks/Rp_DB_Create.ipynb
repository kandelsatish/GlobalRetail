# %%
spark.sql("CREATE DATABASE IF NOT EXISTS rp_globalretail")
spark.sql("USE rp_globalretail")
# Out:
# Out[1]: DataFrame[]

# %%
# %sql 
select current_database()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_database()</th></tr></thead><tbody><tr><td>rp_globalretail</td></tr></tbody></table></div>
